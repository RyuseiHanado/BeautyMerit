# %%
# ログイン処理
# https://chat.openai.com/c/f224d159-3a13-46d2-9470-0f1a0f164ab4

# selenium
# https://chat.openai.com/c/406ac40b-addf-4e35-b04d-49c38d8aa6c3

# %%
# coding: utf-8

# 標準ライブラリのインポート
import sys
import logging

from datetime import datetime
from dateutil.relativedelta import relativedelta

# ローカルモジュールのインポート
sys.path.append('../scripts')
import func_common
import func_selenium
import func_BM
import func_line
import func_Gdrive

# %%
def main():
    # ========================================
    # 初期設定
    # ========================================

    # コード
    func_common.setup_logging()

    config_file_path = '../config/config.ini'  # config.iniファイルのパスを適切に設定してください
    config_values = func_common.read_config_file(config_file_path)
    account_keys = ['Beauty_Merit_Account1', 'Beauty_Merit_Account2', 'Beauty_Merit_Account3']
    downloads_path = '../downloads'
    base_url = "https://b-merit.jp/groupmanage/login/?redirect=1"

    # LINE通知用トークン情報取得
    line_config = config_values['LINE']
    line_access_token = line_config['access_token']

    # アップロード先フォルダID取得
    gdrive_config = config_values['Gdrive']
    upload_folder_id = gdrive_config['upload_folder_id']
    service = func_Gdrive.authenticate_gdrive()


    # ========================================
    # メイン処理
    # ========================================
    message = 'ポイント、売上データの抽出処理を開始します'
    response= func_line.notify_line(line_access_token, message)

    for account_key in account_keys:
        logging.info('================================================================')
        # ログイン処理
        bm_config = config_values[account_key]
        login_id = bm_config['login_id']
        password = bm_config['password']

        driver = func_selenium.set_driver()
        driver.get(base_url)
        logging.info(f"アカウント名：{login_id} でログインします")
        func_BM.perform_login(driver, login_id, password)

        # 店舗名とURLを抽出する
        html_source = driver.page_source
        shop_data = func_BM.extract_shop_data(html_source)

        # 取得したデータが空かどうかチェック
        if len(shop_data) == 0:
            logging.error("店舗名とURLデータの取得に失敗しました。")
            sys.exit(1)
        else:
            logging.info(f"店舗名とURLデータの取得しました。取得件数: {len(shop_data)}")

        # 結果の表示
        for shop in shop_data:
            logging.info(f"{shop['shop_name']}, {shop['url']}")

        # メイン処理
        today = datetime.now()
        target_date = today - relativedelta(days=1) # 前日
        logging.info(f"対象日：{target_date}")
        # ファイル出力用変数
        today = datetime.today().strftime('%Y%m%d')
        login_id = login_id.split('@')[0]
        # ポイント利用情報用の取得、エクスポート
        logging.info('==================================================')
        logging.info('ポイント利用情報用の取得、エクスポート、ファイルアップロード')
        logging.info('==================================================')
        df_all_shops_point = func_BM.process_shop_data(shop_data, driver, line_access_token, target_date)
        if not df_all_shops_point.empty:  # データフレームが空でない場合にcsv出力
            # point_csv_filename = f'{downloads_path}/point_tables_{login_id}_{today}.csv'
            point_csv_filename = f'{downloads_path}/point_tables_{login_id}_{target_date.strftime("%Y%m%d")}.csv'  # ここ追加した。削除必要
            df_all_shops_point.to_csv(point_csv_filename, index=False, encoding='UTF-8')
            logging.info(f'ポイントcsv出力：{point_csv_filename}')
            # GDriveへアップロード
            logging.info(f'GDriveへアップロード')
            func_Gdrive.upload_file(service, point_csv_filename, upload_folder_id)
            logging.info('ポイント利用情報用の取得、エクスポート、ファイルアップロードが完了しました。')
        else:
            logging.warning('ポイント利用情報用の取得するデータがありませんでした。')

        # 売上データ取得、エクスポート
        logging.info('==================================================')
        logging.info('売上データ取得、エクスポート、ファイルアップロード')
        logging.info('==================================================')
        df_all_shops_sales = func_BM.collect_all_shop_data(shop_data, driver, target_date)
        if not df_all_shops_sales.empty:  # データフレームが空でない場合にcsv出力
            # csv出力
            salse_csv_filename = f'{downloads_path}/sales_tables_{login_id}_{target_date.strftime("%Y%m%d")}.csv'  # ファイル名をsales_tablesに変更
            df_all_shops_sales.to_csv(salse_csv_filename, index=False, encoding='UTF-8')
            logging.info(f'売上csv出力：{salse_csv_filename}')
            # GDriveへアップロード
            logging.info(f'GDriveへアップロード')
            func_Gdrive.upload_file(service, salse_csv_filename, upload_folder_id)
            logging.info('売上データ取得、エクスポート、ファイルアップロードが完了しました。')
        else:
            logging.warning('売上データの取得するデータがありませんでした。')

        # 各アカウントの処理が終わったら、ブラウザを閉じます。
        driver.quit()

    message = 'ポイント、売上データの抽出処理を終了しました。'
    response = func_line.notify_line(line_access_token, message)

# %%
if __name__ == "__main__":
    try:
        main()
        logging.info(f"処理が完了しました。")

    except Exception as e:
        logging.info(f"エラーが発生しました: {e}")
    # finally:
        # input("何かキーを押して終了してください...")
# Out:
# 2023-08-30 00:11:57 INFO: Google Driveへの認証が成功しました。
# 2023-08-30 00:11:57 INFO: file_cache is only supported with oauth2client<4.0.0
# 2023-08-30 00:11:57 INFO: LINEへのメッセージ通知に成功しました。： ポイント、売上データの抽出処理を開始します
# 2023-08-30 00:11:57 INFO: ================================================================
# 2023-08-30 00:11:57 INFO: ====== WebDriver manager ======
# 2023-08-30 00:11:58 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:11:58 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:11:58 INFO: There is no [win64] chromedriver "116.0.5845.111" for browser google-chrome "116.0.5845.111" in cache
# 2023-08-30 00:11:58 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:11:58 INFO: WebDriver version 116.0.5845.96 selected
# 2023-08-30 00:11:58 INFO: Modern chrome version https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/116.0.5845.96/win32/chromedriver-win32.zip
# 2023-08-30 00:11:58 INFO: About to download new driver from https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/116.0.5845.96/win32/chromedriver-win32.zip
# 2023-08-30 00:11:59 INFO: Driver downloading response is 200
# 2023-08-30 00:12:01 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:12:01 INFO: Driver has been saved in cache [C:\Users\nh1r0\.wdm\drivers\chromedriver\win64\116.0.5845.111]
# 2023-08-30 00:12:03 INFO: アカウント名：tenectiongroup@a.a でログインします
# 2023-08-30 00:12:03 INFO: ログインプロセスを開始します。
# 2023-08-30 00:12:03 INFO: ログインIDを入力します。
# 2023-08-30 00:12:04 INFO: パスワードを入力します。
# 2023-08-30 00:12:05 INFO: 「ログイン」ボタンをクリックします。
# 2023-08-30 00:12:05 INFO: 店舗名とURLデータの取得しました。取得件数: 11
# 2023-08-30 00:12:05 INFO: INCE HAIR 加古川, https://b-merit.jp/groupmanage/shoplogin/?shop_id=10293&now=1693321926
# 2023-08-30 00:12:05 INFO: INCE HAIR 明石, https://b-merit.jp/groupmanage/shoplogin/?shop_id=10294&now=1693321926
# 2023-08-30 00:12:05 INFO: INCE HAIR 垂水, https://b-merit.jp/groupmanage/shoplogin/?shop_id=10295&now=1693321926
# 2023-08-30 00:12:05 INFO: INCE HAIR 高砂, https://b-merit.jp/groupmanage/shoplogin/?shop_id=10296&now=1693321926
# 2023-08-30 00:12:05 INFO: INCE HAIR 梅田, https://b-merit.jp/groupmanage/shoplogin/?shop_id=10298&now=1693321926
# 2023-08-30 00:12:05 INFO: INCE HAIR 兵庫, https://b-merit.jp/groupmanage/shoplogin/?shop_id=10758&now=1693321926
# 2023-08-30 00:12:05 INFO: Yeeee.s by INCE, https://b-merit.jp/groupmanage/shoplogin/?shop_id=10816&now=1693321926
# 2023-08-30 00:12:05 INFO: INCE HAIR 加古川別府, https://b-merit.jp/groupmanage/shoplogin/?shop_id=11406&now=1693321926
# 2023-08-30 00:12:05 INFO: INCE HAIR 奈良柏木, https://b-merit.jp/groupmanage/shoplogin/?shop_id=11904&now=1693321926
# 2023-08-30 00:12:05 INFO: INCE HAIR
INFO: ポイント利用情報を取得
# 2023-08-30 00:12:31 INFO: {'現金': '11,900 円', 'クレジットカード': '10,900 円', 'ホットペッパービューティー': '100 pt'}
# 2023-08-30 00:12:31 INFO: ------------------------------
# 2023-08-30 00:12:31 INFO: INCE HAIR 岡山ハレまちにログインします。
# 2023-08-30 00:12:32 INFO: INCE HAIR 岡山ハレまちにログインしました。
# 2023-08-30 00:12:32 INFO: レジ締め一覧に移動します：https://b-merit.jp/manage/account/salesclose/?action=list&start_date=2023-08-01&end_date=2023-08-31
# 2023-08-30 00:12:33 INFO: INCE HAIR 岡山ハレまちの売上データを取得します。
# 2023-08-30 00:12:33 INFO: レジ締め日: 2023-08-29, レジ締め対象時間: 2023-08-28 16:21～2023-08-29 19:24, 関連ID: 926929
# 2023-08-30 00:12:33 INFO: 対象日のレジ締め対象ページに移動します：https://b-merit.jp/manage/account/salesclose/?action=detail&id=926929
# 2023-08-30 00:12:34 INFO: ポイント利用情報を取得
# 2023-08-30 00:12:34 INFO: {'現金': '14,800 円', 'クレジット': '14,900 円', 'ホットペッパービューティー': '3,500 pt'}
# 2023-08-30 00:12:34 INFO: ------------------------------
# 2023-08-30 00:12:34 INFO: INCE HAIR 関大前店にログインします。
# 2023-08-30 00:12:35 INFO: INCE HAIR 関大前店にログインしました。
# 2023-08-30 00:12:35 INFO: レジ締め一覧に移動します：https://b-merit.jp/manage/account/salesclose/?action=list&start_date=2023-08-01&end_date=2023-08-31
# 2023-08-30 00:12:35 INFO: INCE HAIR 関大前店の売上データを取得します。
# 2023-08-30 00:12:35 WARNING: INCE HAIR 関大前店にレジ締め情報なし
# 2023-08-30 00:12:35 INFO: LINEへのメッセージ通知に成功しました。： INCE HAIR 関大前店にレジ締め情報なし
# 2023-08-30 00:12:35 INFO: ポイントcsv出力：../downloads/point_tables_tenectiongroup_20230829.csv
# 2023-08-30 00:12:35 INFO: GDriveへアップロード
# 2023-08-30 00:12:35 INFO: ポイント利用情報用の取得、エクスポート、ファイルアップロードが完了しました。
# 2023-08-30 00:12:35 INFO: ==================================================
# 2023-08-30 00:12:35 INFO: 売上データ取得、エクスポート、ファイルアップロード
# 2023-08-30 00:12:35 INFO: ==================================================
# 2023-08-30 00:12:35 INFO: ------------------------------
# 2023-08-30 00:12:35 INFO: INCE HAIR 加古川にログインします。
# 2023-08-30 00:12:36 INFO: INCE HAIR 加古川にログインしました。
# 2023-08-30 00:12:36 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:37 INFO: INCE HAIR 加古川の売上データを取得します。
# 2023-08-30 00:12:37 INFO: ------------------------------
# 2023-08-30 00:12:37 INFO: INCE HAIR 明石にログインします。
# 2023-08-30 00:12:38 INFO: INCE HAIR 明石にログインしました。
# 2023-08-30 00:12:38 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:38 INFO: INCE HAIR 明石の売上データを取得します。
# 2023-08-30 00:12:38 INFO: ------------------------------
# 2023-08-30 00:12:38 INFO: INCE HAIR 垂水にログインします。
# 2023-08-30 00:12:39 INFO: INCE HAIR 垂水にログインしました。
# 2023-08-30 00:12:39 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:40 INFO: INCE HAIR 垂水の売上データを取得します。
# 2023-08-30 00:12:40 INFO: ------------------------------
# 2023-08-30 00:12:40 INFO: INCE HAIR 高砂にログインします。
# 2023-08-30 00:12:41 INFO: INCE HAIR 高砂にログインしました。
# 2023-08-30 00:12:41 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:41 INFO: INCE HAIR 高砂の売上データを取得します。
# 2023-08-30 00:12:41 INFO: ------------------------------
# 2023-08-30 00:12:41 INFO: INCE HAIR 梅田にログインします。
# 2023-08-30 00:12:42 INFO: INCE HAIR 梅田にログインしました。
# 2023-08-30 00:12:42 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:43 INFO: INCE HAIR 梅田の売上データを取得します。
# 2023-08-30 00:12:43 INFO: ------------------------------
# 2023-08-30 00:12:43 INFO: INCE HAIR 兵庫にログインします。
# 2023-08-30 00:12:44 INFO: INCE HAIR 兵庫にログインしました。
# 2023-08-30 00:12:44 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:44 INFO: INCE HAIR 兵庫の売上データを取得します。
# 2023-08-30 00:12:44 INFO: ------------------------------
# 2023-08-30 00:12:44 INFO: Yeeee.s by INCEにログインします。
# 2023-08-30 00:12:45 INFO: Yeeee.s by INCEにログインしました。
# 2023-08-30 00:12:45 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:45 INFO: Yeeee.s by INCEの売上データを取得します。
# 2023-08-30 00:12:45 INFO: ------------------------------
# 2023-08-30 00:12:45 INFO: INCE HAIR 加古川別府にログインします。
# 2023-08-30 00:12:46 INFO: INCE HAIR 加古川別府にログインしました。
# 2023-08-30 00:12:46 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:47 INFO: INCE HAIR 加古川別府の売上データを取得します。
# 2023-08-30 00:12:47 INFO: ------------------------------
# 2023-08-30 00:12:47 INFO: INCE HAIR 奈良柏木にログインします。
# 2023-08-30 00:12:48 INFO: INCE HAIR 奈良柏木にログインしました。
# 2023-08-30 00:12:48 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:48 INFO: INCE HAIR 奈良柏木の売上データを取得します。
# 2023-08-30 00:12:48 INFO: ------------------------------
# 2023-08-30 00:12:48 INFO: INCE HAIR 岡山ハレまちにログインします。
# 2023-08-30 00:12:49 INFO: INCE HAIR 岡山ハレまちにログインしました。
# 2023-08-30 00:12:49 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:49 INFO: INCE HAIR 岡山ハレまちの売上データを取得します。
# 2023-08-30 00:12:49 INFO: ------------------------------
# 2023-08-30 00:12:49 INFO: INCE HAIR 関大前店にログインします。
# 2023-08-30 00:12:50 INFO: INCE HAIR 関大前店にログインしました。
# 2023-08-30 00:12:50 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:12:51 INFO: INCE HAIR 関大前店の売上データを取得します。
# 2023-08-30 00:12:51 INFO: 売上csv出力：../downloads/sales_tables_tenectiongroup_20230829.csv
# 2023-08-30 00:12:51 INFO: GDriveへアップロード
# 2023-08-30 00:12:51 INFO: 売上データ取得、エクスポート、ファイルアップロードが完了しました。
# 2023-08-30 00:12:53 INFO: ================================================================
# 2023-08-30 00:12:53 INFO: ====== WebDriver manager ======
# 2023-08-30 00:12:54 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:12:54 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:12:54 INFO: There is no [win64] chromedriver "116.0.5845.111" for browser google-chrome "116.0.5845.111" in cache
# 2023-08-30 00:12:54 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:12:54 INFO: WebDriver version 116.0.5845.96 selected
# 2023-08-30 00:12:54 INFO: Modern chrome version https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/116.0.5845.96/win32/chromedriver-win32.zip
# 2023-08-30 00:12:54 INFO: About to download new driver from https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/116.0.5845.96/win32/chromedriver-win32.zip
# 2023-08-30 00:12:54 INFO: Driver downloading response is 200
# 2023-08-30 00:12:56 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:12:57 INFO: Driver has been saved in cache [C:\Users\nh1r0\.wdm\drivers\chromedriver\win64\116.0.5845.111]
# 2023-08-30 00:13:02 INFO: アカウント名：agelessgroup@a.a でログインします
# 2023-08-30 00:13:02 INFO: ログインプロセスを開始します。
# 2023-08-30 00:13:02 INFO: ログインIDを入力します。
# 2023-08-30 00:13:04 INFO: パスワードを入力します。
# 2023-08-30 00:13:05 INFO: 「ログイン」ボタンをクリックします。
# 2023-08-30 00:13:05 INFO: 店舗名とURLデータの取得しました。取得件数: 2
# 2023-08-30 00:13:05 INFO: ageless, https://b-merit.jp/groupmanage/shoplogin/?shop_id=10297&now=1693321985
# 2023-08-30 00:13:05 INFO: odd. by ageless, https://b-merit.jp/groupmanage/shoplogin/?shop_id=11907&now=1693321985
# 2023-08-30 00:13:05 INFO: 対象日：2023-08-29 00:13:05.412448
# 2023-08-30 00:13:05 INFO: ==================================================
# 2023-08-30 00:13:05 INFO: ポイント利用情報用の取得、エクスポート、ファイルアップロード
# 2023-08-30 00:13:05 INFO: ==================================================
# 2023-08-30 00:13:05 INFO: ------------------------------
# 2023-08-30 00:13:05 INFO: agelessにログインします。
# 2023-08-30 00:13:06 INFO: agelessにログインしました。
# 2023-08-30 00:13:06 INFO: レジ締め一覧に移動します：https://b-merit.jp/manage/account/salesclose/?action=list&start_date=2023-08-01&end_date=2023-08-31
# 2023-08-30 00:13:07 INFO: agelessの売上データを取得します。
# 2023-08-30 00:13:07 INFO: レジ締め日: 2023-08-29, レジ締め対象時間: 2023-08-28 21:44～2023-08-29 20:11, 関連ID: 927162
# 2023-08-30 00:13:07 INFO: 対象日のレジ締め対象ページに移動します：https://b-merit.jp/manage/account/salesclose/?action=detail&id=927162
# 2023-08-30 00:13:08 INFO: ポイント利用情報を取得
# 2023-08-30 00:13:08 INFO: {'現金': '97,400 円', 'スマート支払い(SYSTEM)': '42,000 円', 'クレジット': '33,100 円'}
# 2023-08-30 00:13:08 INFO: ------------------------------
# 2023-08-30 00:13:08 INFO: odd. by agelessにログインします。
# 2023-08-30 00:13:09 INFO: odd. by agelessにログインしました。
# 2023-08-30 00:13:09 INFO: レジ締め一覧に移動します：https://b-merit.jp/manage/account/salesclose/?action=list&start_date=2023-08-01&end_date=2023-08-31
# 2023-08-30 00:13:09 INFO: odd. by agelessの売上データを取得します。
# 2023-08-30 00:13:09 INFO: レジ締め日: 2023-08-29, レジ締め対象時間: 2023-08-28 21:47～2023-08-29 19:19, 関連ID: 926914
# 2023-08-30 00:13:09 INFO: 対象日のレジ締め対象ページに移動します：https://b-merit.jp/manage/account/salesclose/?action=detail&id=926914
# 2023-08-30 00:13:10 INFO: ポイント利用情報を取得
# 2023-08-30 00:13:10 INFO: {'現金': '0 円', 'クレジットカード': '120,700 円'}
# 2023-08-30 00:13:10 INFO: ポイントcsv出力：../downloads/point_tables_agelessgroup_20230829.csv
# 2023-08-30 00:13:10 INFO: GDriveへアップロード
# 2023-08-30 00:13:10 INFO: ポイント利用情報用の取得、エクスポート、ファイルアップロードが完了しました。
# 2023-08-30 00:13:10 INFO: ==================================================
# 2023-08-30 00:13:10 INFO: 売上データ取得、エクスポート、ファイルアップロード
# 2023-08-30 00:13:10 INFO: ==================================================
# 2023-08-30 00:13:10 INFO: ------------------------------
# 2023-08-30 00:13:10 INFO: agelessにログインします。
# 2023-08-30 00:13:11 INFO: agelessにログインしました。
# 2023-08-30 00:13:11 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:13:12 INFO: agelessの売上データを取得します。
# 2023-08-30 00:13:12 INFO: ------------------------------
# 2023-08-30 00:13:12 INFO: odd. by agelessにログインします。
# 2023-08-30 00:13:12 INFO: odd. by agelessにログインしました。
# 2023-08-30 00:13:12 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:13:13 INFO: odd. by agelessの売上データを取得します。
# 2023-08-30 00:13:13 INFO: 売上csv出力：../downloads/sales_tables_agelessgroup_20230829.csv
# 2023-08-30 00:13:13 INFO: GDriveへアップロード
# 2023-08-30 00:13:13 INFO: 売上データ取得、エクスポート、ファイルアップロードが完了しました。
# 2023-08-30 00:13:15 INFO: ================================================================
# 2023-08-30 00:13:15 INFO: ====== WebDriver manager ======
# 2023-08-30 00:13:16 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:13:16 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:13:16 INFO: There is no [win64] chromedriver "116.0.5845.111" for browser google-chrome "116.0.5845.111" in cache
# 2023-08-30 00:13:16 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:13:16 INFO: WebDriver version 116.0.5845.96 selected
# 2023-08-30 00:13:16 INFO: Modern chrome version https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/116.0.5845.96/win32/chromedriver-win32.zip
# 2023-08-30 00:13:16 INFO: About to download new driver from https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/116.0.5845.96/win32/chromedriver-win32.zip
# 2023-08-30 00:13:16 INFO: Driver downloading response is 200
# 2023-08-30 00:13:19 INFO: Get LATEST chromedriver version for google-chrome
# 2023-08-30 00:13:19 INFO: Driver has been saved in cache [C:\Users\nh1r0\.wdm\drivers\chromedriver\win64\116.0.5845.111]
# 2023-08-30 00:13:25 INFO: アカウント名：lunegroup@a.a でログインします
# 2023-08-30 00:13:25 INFO: ログインプロセスを開始します。
# 2023-08-30 00:13:25 INFO: ログインIDを入力します。
# 2023-08-30 00:13:26 INFO: パスワードを入力します。
# 2023-08-30 00:13:27 INFO: 「ログイン」ボタンをクリックします。
# 2023-08-30 00:13:27 INFO: 店舗名とURLデータの取得しました。取得件数: 1
# 2023-08-30 00:13:27 INFO: Lune.女性専門サロン, https://b-merit.jp/groupmanage/shoplogin/?shop_id=10299&now=1693322007
# 2023-08-30 00:13:27 INFO: 対象日：2023-08-29 00:13:27.595299
# 2023-08-30 00:13:27 INFO: ==================================================
# 2023-08-30 00:13:27 INFO: ポイント利用情報用の取得、エクスポート、ファイルアップロード
# 2023-08-30 00:13:27 INFO: ==================================================
# 2023-08-30 00:13:27 INFO: ------------------------------
# 2023-08-30 00:13:27 INFO: Lune.女性専門サロンにログインします。
# 2023-08-30 00:13:29 INFO: Lune.女性専門サロンにログインしました。
# 2023-08-30 00:13:29 INFO: レジ締め一覧に移動します：https://b-merit.jp/manage/account/salesclose/?action=list&start_date=2023-08-01&end_date=2023-08-31
# 2023-08-30 00:13:29 INFO: Lune.女性専門サロンの売上データを取得します。
# 2023-08-30 00:13:29 INFO: レジ締め日: 2023-08-29, レジ締め対象時間: 2023-08-28 18:13～2023-08-29 19:16, 関連ID: 926897
# 2023-08-30 00:13:29 INFO: 対象日のレジ締め対象ページに移動します：https://b-merit.jp/manage/account/salesclose/?action=detail&id=926897
# 2023-08-30 00:13:30 INFO: ポイント利用情報を取得
# 2023-08-30 00:13:30 INFO: {'現金': '54,600 円', 'スマート支払い(SYSTEM)': '5,700 円', 'クレジット': '37,400 円', '電子マネー': '36,300 円', 'ホットペッパービューティー': '200 pt'}
# 2023-08-30 00:13:30 INFO: ポイントcsv出力：../downloads/point_tables_lunegroup_20230829.csv
# 2023-08-30 00:13:30 INFO: GDriveへアップロード
# 2023-08-30 00:13:30 INFO: ポイント利用情報用の取得、エクスポート、ファイルアップロードが完了しました。
# 2023-08-30 00:13:30 INFO: ==================================================
# 2023-08-30 00:13:30 INFO: 売上データ取得、エクスポート、ファイルアップロード
# 2023-08-30 00:13:30 INFO: ==================================================
# 2023-08-30 00:13:30 INFO: ------------------------------
# 2023-08-30 00:13:30 INFO: Lune.女性専門サロンにログインします。
# 2023-08-30 00:13:31 INFO: Lune.女性専門サロンにログインしました。
# 2023-08-30 00:13:31 INFO: 売上分析ページに移動します。https://b-merit.jp/manage/analysis/account?periodType=0&startDay=2023-08-01&endDay=2023-08-31
# 2023-08-30 00:13:32 INFO: Lune.女性専門サロンの売上データを取得します。
# 2023-08-30 00:13:32 INFO: 売上csv出力：../downloads/sales_tables_lunegroup_20230829.csv
# 2023-08-30 00:13:32 INFO: GDriveへアップロード
# 2023-08-30 00:13:32 INFO: 売上データ取得、エクスポート、ファイルアップロードが完了しました。
# 2023-08-30 00:13:34 INFO: LINEへのメッセージ通知に成功しました。： ポイント、売上データの抽出処理を終了しました。
# 2023-08-30 00:13:38 INFO: 処理が完了しました。
